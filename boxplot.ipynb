# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("food_coded.csv")

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df.drop(columns=['type_sports'])
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
sg =df.drop(columns=['GPA','breakfast','calories_chicken','calories_day','calories_scone','coffee','comfort_food','comfort_food_reasons','comfort_food_reasons_coded','comfort_food_reasons_coded','cuisine','diet_current','diet_current_coded','drink','eating_changes','eating_changes_coded','eating_changes_coded1','father_education','father_profession','fav_cuisine_coded','food_childhood','fries','grade_level','greek_food','healthy_feeling','ideal_diet','ideal_diet_coded','life_rewarding','mother_education','mother_profession','nutritional_check','self_perception_weight','sports','tortilla_calories','turkey_calories','type_sports','vitamins','waffle_calories','meals_dinner_friend','fav_food','healthy_meal','parents_cook','exercise','comfort_food_reasons_coded.1','weight','marital_status']).dropna()

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
sg.to_csv('cleaned_data.csv')

# %%
df.boxplot(by = 'cook', column =['income'], grid = False)
# Out:
# <AxesSubplot:title={'center':'income'}, xlabel='cook'>

# %%
df1= pd.DataFrame(data=df,columns=['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus',
                                  'pay_meal_out','veggies_day'])

# %%
bp_dict=df1.boxplot(rot=45,fontsize=15,return_type='both',patch_artist=True)
